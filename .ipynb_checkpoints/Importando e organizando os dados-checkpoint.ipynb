# %% [markdown]
# # Importando os pacotes mais relevantes

# %%
# Trabalhar com arrays n-dimensionais
import numpy as np

# Criação de tabelas e organização de dados de forma visualmente mais efetiva. Consegue lidar com séries de dados temporais e bancos de dados
import pandas as pd
import pandas_datareader as wb

# biblioteca de gráficos 2D para trabalhar com dados tratados com pandas
import matplotlib

# funções matemáticas
import math

# geração de números aleatórios
import random

# estatística descritiva, gráficos, regressões
import statsmodels

# %%
EMBR3 = wb.DataReader('')
